# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
import glob
import os, sys
import mpl_scatter_density
import mplhep as hep

sys.path.append('../')
from utils import load
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
epoch = 99

# %%
prefix = '/export/home/phys/kyungmip/L1DeepMETv2_workspace/'
ckpts = f'{prefix}/ckpts_Feb16_edgeConv_4layers_batch32_noSelfLoops_noResponseCorr_correctUt/'

# %%
plt.style.use(hep.style.CMS)

a=load(ckpts + '/best.resolutions')
colors = {
#    'pfMET': 'black',
#    'puppiMET': 'red',
#    'deepMETResponse': 'blue',
#    'deepMETResolution': 'green',
    'MET':  'magenta',
}
label_arr = {
    'MET':     'Graph MET' ,
#    'pfMET':    'PF MET',
#    'puppiMET': 'PUPPI MET',
#    'deepMETResponse': 'DeepMETResponse',
#    'deepMETResolution': 'DeepMETResolution',
}
resolutions_arr = {
    'MET':      [[],[],[]],
#    'pfMET':    [[],[],[]],
#    'puppiMET': [[],[],[]],
#    'deepMETResponse': [[],[],[]],
#    'deepMETResolution': [[],[],[]],
}

# %%
for key in resolutions_arr:
    #plt.figure(1)
    #xx = a[key]['u_perp_resolution'][1][0:40]
    #yy = a[key]['u_perp_resolution'][0]
         
    #plt.plot(xx, yy,color=colors[key], label=label_arr[key])
    plt.figure(2)
    xx = a[key]['u_perp_scaled_resolution'][1][0:40]
    yy = a[key]['u_perp_scaled_resolution'][0]
         
    plt.plot(xx, yy,color=colors[key], label=label_arr[key])
    plt.xlim([10,400])
    
    #plt.figure(3)
    #xx = a[key]['u_par_resolution'][1][0:40]
    #yy = a[key]['u_par_resolution'][0]
         
    #plt.plot(xx, yy,color=colors[key], label=label_arr[key])
    plt.figure(4)
    xx = a[key]['u_par_scaled_resolution'][1][0:40]
    yy = a[key]['u_par_scaled_resolution'][0]
         
    plt.plot(xx, yy,color=colors[key], label=label_arr[key])
    plt.xlim([10,400])
    
    plt.figure(5)
    xx = a[key]['R'][1][0:40]
    yy = a[key]['R'][0]
    plt.plot(xx, yy,color=colors[key], label=label_arr[key])
    
    plt.xlim([10,400])
    plt.ylim([0,1.5])

# %%
true_px_txt = glob.glob('{}/epoch{}_*true_px*'.format(ckpts, epoch))[0]
true_py_txt = glob.glob('{}/epoch{}_*true_py*'.format(ckpts, epoch))[0]
METx_txt = glob.glob('{}/epoch{}_*METx*'.format(ckpts, epoch))[0]
METy_txt = glob.glob('{}/epoch{}_*METy*'.format(ckpts, epoch))[0]

# %%
true_px_arr = np.loadtxt(true_px_txt, delimiter=',')
true_py_arr = np.loadtxt(true_py_txt, delimiter=',')
METx_arr = np.loadtxt(METx_txt, delimiter=',')
METy_arr = np.loadtxt(METy_txt, delimiter=',')

# %% [markdown]
# ### Plot predicted vs. gen MET

# %%
plt.scatter(true_px_arr, -METx_arr, s=1, alpha=0.7)
plt.xlabel('Gen METx')
plt.ylabel('Predicted METx')
plt.title(f'METx (Epoch {epoch})')
# Out:
# Text(0.5, 1.0, 'METx (Epoch 99)')

# %%
plt.scatter(true_py_arr, -METy_arr, s=1, alpha=0.7)
plt.xlabel('Gen METy')
plt.ylabel('Predicted METy')
plt.title(f'METy (Epoch {epoch})')
# Out:
# Text(0.5, 1.0, 'METy (Epoch 99)')

# %%
true_pT = np.sqrt(true_px_arr **2 + true_py_arr **2)
MET = np.sqrt(METx_arr **2 + METy_arr **2)

# %%
plt.scatter(true_pT, MET, s=0.5, alpha=0.7)
plt.xlabel('Gen MET')
plt.ylabel('Predicted MET')
plt.title(f'MET (Epoch {epoch})')
# Out:
# Text(0.5, 1.0, 'MET (Epoch 99)')

# %% [markdown]
# ### Calculate and plot the response

# %%
response_pT = MET / true_pT

# %%
response_pT.mean()
# Out:
# 0.9891654696010461

# %%
# Bin the MET
nbins = 20
binnings = np.linspace(0, 400, num=nbins+1)

# Using the binning information, put the response_pT into the binned list
from scipy.stats import binned_statistic
truth_means, bin_edges, binnumber = binned_statistic(true_pT, true_pT, statistic='mean', bins=binnings, range=(0, 400))
ml_means,  _, _ = binned_statistic(true_pT, MET, statistic='mean', bins=binnings, range=(0, 400))

# Take the mean for each bin
response = ml_means / truth_means

# %%
truth_means
# Out:
# array([ 13.22025953,  30.78422126,  50.17433182,  69.74866137,
#         89.42418645, 109.15271446, 129.0565839 , 149.01638324,
#        168.98912076, 189.06215684, 208.95865137, 229.40955316,
#        249.1626088 , 269.1519751 , 289.50862898, 309.39020296,
#        330.3104444 , 349.80810408, 369.0422658 , 389.75504141])

# %%
ml_means
# Out:
# array([ 34.00969208,  37.82379037,  44.86002845,  53.62256548,
#         63.54837475,  74.76952735,  86.76861372, 101.0232566 ,
#        115.78061369, 132.03724181, 148.94395929, 163.13980067,
#        176.44907457, 186.55984538, 210.83783081, 215.63055608,
#        241.03840036, 258.52050474, 263.56631262, 281.03837426])

# %%
binnings
# Out:
# array([  0.,  20.,  40.,  60.,  80., 100., 120., 140., 160., 180., 200.,
#        220., 240., 260., 280., 300., 320., 340., 360., 380., 400.])

# %%
response
# Out:
# array([2.57254345, 1.22867459, 0.89408323, 0.76879706, 0.71063967,
#        0.68499925, 0.67233001, 0.67793389, 0.68513649, 0.69838007,
#        0.71279154, 0.71112906, 0.70816835, 0.69313943, 0.72826096,
#        0.69695341, 0.72973291, 0.73903521, 0.71419005, 0.72106412])

# %%
plt.hlines(truth_means/truth_means, bin_edges[:-1], bin_edges[1:], colors='k', lw=5,
               label='Truth', linestyles='solid')
plt.hlines(ml_means/truth_means, bin_edges[:-1], bin_edges[1:], colors='r', lw=5,
               label='ML', linestyles='solid')

plt.ylim(0, 1.5)
plt.xlabel('Truth MET [GeV]')
plt.legend(loc='lower right')
plt.ylabel(f'Response / {binnings[1]-binnings[0]:.0f} GeV')

plt.title('Response (no response correction)')
# Out:
# Text(0.5, 1.0, 'Response (no response correction)')

# %% [markdown]
# ### Plot MET

# %%
genMET = np.array(true_pT)
genMET_binned = []

nbins = 20
binnings = np.linspace(0, 400, num=nbins+1)

for idx in range(len(binnings)-1):
    genMET_binned.append( np.logical_and(genMET > binnings[idx], genMET < binnings[idx+1]) )

# %%
MLMET = np.array(MET)
MLMET_binned = []

for idx in range(len(binnings)-1):
    MLMET_binned.append( np.logical_and(MLMET > binnings[idx], MLMET < binnings[idx+1]) )

# %%
genMET_binned_entries = [sum(genMET_binned[i]) for i in range(len(genMET_binned))]

# %%
MLMET_binned_entries = [sum(MLMET_binned[i]) for i in range(len(MLMET_binned))]

# %%
import ROOT as r

hGenMET = r.TH1D('genMET', 'genMET', nbins, 0, 400)
hMLMET = r.TH1D('MLMET', 'MLMET', nbins, 0, 400)

# %%
for i in range(nbins):
    hGenMET.SetBinContent(i+1, genMET_binned_entries[i])
    hMLMET.SetBinContent(i+1, MLMET_binned_entries[i])

# %%
r.gStyle.SetOptStat(0)

c = r.TCanvas()

hMLMET.Draw()
hMLMET.GetXaxis().SetTitle('MET')
hMLMET.GetYaxis().SetTitle('Events / 20GeV')
hMLMET.SetTitle('MET')
hGenMET.Draw('SAME')

hMLMET.SetLineColor(2)
hGenMET.SetLineColor(4)

legend = r.TLegend(0.7,0.75,0.9,0.85)
r.gStyle.SetLegendBorderSize(0)
legend.AddEntry(hMLMET,"ML MET","f")
legend.AddEntry(hGenMET,"GenMET","l")
legend.Draw('SAME')

#c.SetLogy()

c.Draw()
